# %% [markdown]
# <a href="https://colab.research.google.com/github/battinilokesh/Lending-club-case-study/blob/main/Mastering_K_Means_Clustering_in_Unsupervised_Lear_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Mastering K-Means Clustering: A Deep Dive**
#
# K-Means Clustering is a popular unsupervised machine learning algorithm used to group similar data points together. It's a versatile technique with applications in various fields, from customer segmentation to image compression.
#
# **How K-Means Works:**
#
# 1. **Initialization:**
#    * Choose the number of clusters, `k`.
#    * Randomly select `k` data points as initial centroids.
#
# 2. **Assignment:**
#    * Assign each data point to the nearest centroid based on Euclidean distance.
#
# 3. **Update Centroids:**
#    * Calculate the mean of all data points assigned to each cluster.
#    * Update the centroids to the new mean values.
#
# 4. **Iteration:**
#    * Repeat steps 2 and 3 until convergence, i.e., the centroids no longer change significantly.
#
# **Implementation in Python with Scikit-learn:**

# %%
from sklearn.cluster import KMeans
import numpy as np

# Sample data
X = np.array([[1, 2], [1, 4], [1, 0],
              [10, 2], [10, 4], [10, 0]])

# Create a KMeans instance with 2 clusters
kmeans = KMeans(n_clusters=2, random_state=0).fit(X)

# Get the cluster labels
labels = kmeans.labels_
print(labels)

# Get the cluster centers
centroids = kmeans.cluster_centers_
print(centroids)
# Out:
# [1 1 1 0 0 0]
# [[10.  2.]
#  [ 1.  2.]]

# %% [markdown]
# **Choosing the Optimal Number of Clusters (k):**
#
# * **Elbow Method:**
#   * Calculate the within-cluster sum-of-squares (WCSS) for different values of `k`.
#   * Plot the WCSS against `k`.
#   * The "elbow" point, where the curve starts to bend, indicates the optimal `k`.

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Calculate WCSS for different values of k
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=200, n_init=10, random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

# Plot the results
plt.plot(range(1, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('wcss')
plt.show()

# %% [markdown]
# **Key Considerations and Advanced Techniques:**
#
# * **Initialization:** Random initialization can lead to different results. Techniques like K-Means++ can improve initialization.
# * **Distance Metrics:** Euclidean distance is commonly used, but other metrics like Manhattan distance or cosine similarity can be appropriate depending on the data.
# * **Feature Scaling:** Scaling features can significantly impact clustering results, especially when features have different ranges.
# * **Evaluation:** While K-Means is unsupervised, techniques like silhouette analysis can be used to assess the quality of clustering.
# * **Mini-Batch K-Means:** For large datasets, Mini-Batch K-Means can be more efficient by using smaller subsets of data.
#
# **Applications of K-Means:**
#
# * **Customer Segmentation:** Grouping customers based on purchasing behavior.
# * **Image Compression:** Reducing image size by clustering similar color pixels.
# * **Document Clustering:** Organizing documents into thematic groups.
# * **Anomaly Detection:** Identifying outliers by clustering normal data points.
#
# By understanding the core concepts and practical implementation of K-Means, you can effectively apply this powerful algorithm to various data mining and machine learning tasks.
#
# **Would you like to delve deeper into a specific aspect of K-Means, such as handling outliers, feature engineering, or evaluating clustering results?**

# %% [markdown]
# <div class="md-recitation">
#   Sources
#   <ol>
#   <li><a href="https://github.com/thomassshaw/outlier-blog">https://github.com/thomassshaw/outlier-blog</a></li>
#   <li><a href="https://github.com/goktugkorkulu/Turkey-Inflation-Data-Analysis">https://github.com/goktugkorkulu/Turkey-Inflation-Data-Analysis</a></li>
#   </ol>
# </div>

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np

# Sample data for illustration purposes
# Ensure you have your data loaded in X
# For example:
X = np.random.rand(100, 2)  # Replace this with your actual data

# Calculate WCSS for different values of k
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

# Plot the results
plt.plot(range(1, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')

plt.ylabel('wcss')
plt.show()

# %% [markdown]
# Calculating WCSS (Within-Cluster Sum of Squares) for different values of k:
#
# wcss = []: Initialize an empty list to store WCSS values.
#
# for i in range(1, 11):: Loop over values of k from 1 to 10.
#
# kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0): Initialize the KMeans algorithm with i clusters.
#
# kmeans.fit(X): Fit the model to the data X.
#
# wcss.append(kmeans.inertia_): Append the inertia (WCSS) of the model to the wcss list.
#
# Plotting the results:
#
# plt.plot(range(1, 11), wcss): Plot the WCSS values against the number of clusters.
#
# plt.title('Elbow Method'): Set the plot title.
#
# plt.xlabel('Number of clusters'): Label the x-axis.
#
# plt.ylabel('WCSS'): Label the y-axis.
#
# plt.show(): Display the plot.
#
# # By plotting the WCSS values against the number of clusters, you can visually inspect the "elbow" point. This point is where the WCSS starts to decrease more slowly, suggesting a good balance between the number of clusters and the amount of variance captured.**bold text**

# %%
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Sample data (replace with your actual data)
X = np.random.rand(100, 2)

# Choose the number of clusters
k = 3

# Initialize the K-Means model
kmeans = KMeans(n_clusters=k, init='k-means++', max_iter=300, n_init=10, random_state=0)

# Fit the model to the data
kmeans.fit(X)

# Get the cluster centers and labels
centers = kmeans.cluster_centers_
labels = kmeans.labels_

# Plot the clustered data
plt.scatter(X[:, 0], X[:, 1], c=labels, s=50, cmap='viridis')
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=200, alpha=0.75, marker='x')
plt.title('K-Means Clustering')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %% [markdown]
# Iterating the K-Means clustering algorithm is a core aspect of unsupervised learning to find the optimal cluster centers. Here’s a step-by-step breakdown of how the K-Means algorithm works:
#
# ### Step-by-Step K-Means Clustering
#
# 1. **Initialize the Centers**:
#    - Choose the number of clusters \( k \).
#    - Randomly select \( k \) initial cluster centers (centroids).
#
# 2. **Assign Clusters**:
#    - Assign each data point to the nearest cluster center based on the Euclidean distance.
#
# 3. **Update Centers**:
#    - Calculate the mean of all the points in each cluster and set the new cluster center to this mean.
#
# 4. **Repeat**:
#    - Repeat steps 2 and 3 until the cluster centers do not change significantly or the maximum number of iterations is reached.
#
# ### Code Implementation with Iteration
#
# Here’s a sample code to iterate the K-Means clustering algorithm:
#
# ```python
# import numpy as np
# from sklearn.cluster import KMeans
# import matplotlib.pyplot as plt
#
# # Sample data (replace with your actual data)
# X = np.random.rand(100, 2)
#
# # Choose the number of clusters
# k = 3
#
# # Initialize the K-Means model
# kmeans = KMeans(n_clusters=k, init='k-means++', max_iter=300, n_init=10, random_state=0)
#
# # Fit the model to the data
# kmeans.fit(X)
#
# # Get the cluster centers and labels
# centers = kmeans.cluster_centers_
# labels = kmeans.labels_
#
# # Plot the clustered data
# plt.scatter(X[:, 0], X[:, 1], c=labels, s=50, cmap='viridis')
# plt.scatter(centers[:, 0], centers[:, 1], c='red', s=200, alpha=0.75, marker='x')
# plt.title('K-Means Clustering')
# plt.xlabel('Feature 1')
# plt.ylabel('Feature 2')
# plt.show()
# ```
#
# ### Important Considerations
#
# - **Choosing \( k \)**: The Elbow Method is commonly used to determine the optimal number of clusters.
# - **Scaling**: Data should be scaled before applying K-Means to ensure that each feature contributes equally to the distance calculations.
# - **Convergence**: K-Means is guaranteed to converge, but it might converge to a local minimum. Running the algorithm multiple times with different initializations (`n_init`) can help find a better solution.
#
# This iterative process ensures that the algorithm fine-tunes the cluster centers to best fit the data.
